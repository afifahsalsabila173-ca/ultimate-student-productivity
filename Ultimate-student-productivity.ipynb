# %% [markdown]
# <a href="https://colab.research.google.com/github/afifahsalsabila173-ca/ultimate-student-productivity/blob/main/Ultimate-student-productivity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("ultimate_student_productivity_dataset_5000.csv")
print(df.head())
# Out:
#    student_id  age gender academic_level  study_hours  self_study_hours  \
# 0           1   18  Other    High School         7.64              1.56
# 1           2   18  Other    High School         2.21              2.22
# 2           3   22   Male    High School         3.45              0.00
# 3           4   17  Other    High School         5.75              2.08
# 4           5   19  Other    High School         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  2.20                3.05          2.19         6.52  ...
# 1                  2.10                1.65          2.55         5.97  ...
# 2                  0.29                1.34          2.08         8.39  ...
# 3                  3.01                2.27          2.20         6.31  ...
# 4                  3.33                2.65          0.70         8.01  ...
#
# ...

# %% [markdown]
# Berisi data 5000 siswa dengan informasi usia, jenis kelamin, tingkat pendidikan, jam belajar, aktivitas non-akademik, kondisi eksternal, kesehatan mental, fokus, burnout, serta skor produktivitas dan nilai ujian. Dari data terlihat bahwa produktivitas siswa dipengaruhi oleh beberapa faktor, antara lain jam belajar, aktivitas sosial dan gaming, kualitas tidur, kesehatan mental, fokus, burnout, serta kondisi eksternal seperti pekerjaan paruh waktu dan kualitas internet. Siswa yang lebih fokus, sehat, dan memiliki manajemen waktu baik cenderung memiliki skor produktivitas lebih tinggi, meskipun nilai ujian tidak selalu tinggi, menunjukkan adanya pengaruh kompleks antara perilaku, kondisi, dan produktivitas.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            5000 non-null   int64
#  1   age                   5000 non-null   int64
#  2   gender                5000 non-null   object
#  3   academic_level        5000 non-null   object
#  4   study_hours           5000 non-null   float64
#  5   self_study_hours      5000 non-null   float64
#  6   online_classes_hours  5000 non-null   float64
#  7   social_media_hours    5000 non-null   float64
#  8   gaming_hours          5000 non-null   float64
#  9   sleep_hours           5000 non-null   float64
#  10  screen_time_hours     5000 non-null   float64
#  11  exercise_minutes      5000 non-null   int64
#  12  caffeine_intake_mg    5000 non-null   int64
#  13  part_time_job         5000 non-null   int64
#  14  upcoming_deadline     5000 non-null   int64
# ...

# %% [markdown]
# Dataset ini terdiri dari 5.000 data siswa dengan 21 variabel dan tidak memiliki nilai kosong pada seluruh kolom. Variabel yang tersedia mencakup karakteristik siswa, kebiasaan belajar, penggunaan waktu, kondisi kesehatan mental, hingga hasil akademik. Dengan kombinasi data numerik dan kategorikal yang lengkap, dataset ini siap digunakan untuk analisis lebih lanjut tanpa memerlukan proses pembersihan data awal.

# %%
print(df.describe())
# Out:
#         student_id          age  study_hours  self_study_hours  \
# count  5000.000000  5000.000000  5000.000000       5000.000000
# mean   2500.500000    20.520400     4.539594          2.478734
# std    1443.520003     2.870406     1.821665          1.177990
# min       1.000000    16.000000     0.000000          0.000000
# 25%    1250.750000    18.000000     3.250000          1.660000
# 50%    2500.500000    20.000000     4.530000          2.480000
# 75%    3750.250000    23.000000     5.760000          3.290000
# max    5000.000000    25.000000    11.840000          7.410000
#
#        online_classes_hours  social_media_hours  gaming_hours  sleep_hours  \
# count           5000.000000         5000.000000   5000.000000  5000.000000
# mean               2.011984            2.998086      1.564514     7.016492
# std                0.983906            1.467949      1.110807     1.163692
# min                0.000000            0.000000      0.000000     4.000000
# ...

# %% [markdown]
# Hasil statistik deskriptif menunjukkan gambaran umum sebaran data siswa, seperti rata-rata usia sekitar 20 tahun, waktu belajar sekitar 4,5 jam per hari, waktu tidur sekitar 7 jam, serta penggunaan screen time hampir 7 jam. Nilai minimum, maksimum, dan kuartil menunjukkan variasi perilaku belajar, gaya hidup, dan kondisi mental siswa yang cukup beragam, sehingga data ini representatif untuk dianalisis lebih lanjut terkait faktor-faktor yang memengaruhi fokus, burnout, dan hasil akademik.

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'academic_level', 'study_hours',
#        'self_study_hours', 'online_classes_hours', 'social_media_hours',
#        'gaming_hours', 'sleep_hours', 'screen_time_hours', 'exercise_minutes',
#        'caffeine_intake_mg', 'part_time_job', 'upcoming_deadline',
#        'internet_quality', 'mental_health_score', 'focus_index',
#        'burnout_level', 'productivity_score', 'exam_score'],
#       dtype='object')

# %% [markdown]
# Output tersebut menampilkan seluruh variabel dalam dataset yang berjumlah 21 kolom, meliputi identitas siswa, karakteristik demografis, kebiasaan belajar, penggunaan waktu, gaya hidup, kondisi kesehatan mental, produktivitas, hingga nilai ujian. Informasi ini menunjukkan bahwa dataset memiliki variabel yang lengkap dan relevan untuk menganalisis faktor-faktor yang memengaruhi produktivitas dan prestasi belajar siswa.

# %%
import pandas as pd
df = pd.read_csv("ultimate_student_productivity_dataset_5000.csv")
df.columns = df.columns.map(str).str.strip()
df.head()
# Out:
#    student_id  age gender academic_level  study_hours  self_study_hours  \
# 0           1   18  Other    High School         7.64              1.56
# 1           2   18  Other    High School         2.21              2.22
# 2           3   22   Male    High School         3.45              0.00
# 3           4   17  Other    High School         5.75              2.08
# 4           5   19  Other    High School         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  2.20                3.05          2.19         6.52  ...
# 1                  2.10                1.65          2.55         5.97  ...
# 2                  0.29                1.34          2.08         8.39  ...
# 3                  3.01                2.27          2.20         6.31  ...
# 4                  3.33                2.65          0.70         8.01  ...
#
# ...

# %% [markdown]
# data berhasil dimuat dengan benar serta memberikan gambaran awal mengenai struktur data, jenis variabel, dan isi setiap kolom sebelum dilakukan analisis lebih lanjut.

# %%
import pandas as pd
df = pd.read_csv("ultimate_student_productivity_dataset_5000.csv")
df.columns = df.columns.map(str).str.strip()
print("Kolom dataset:", df.columns)
# Out:
# Kolom dataset: Index(['student_id', 'age', 'gender', 'academic_level', 'study_hours',
#        'self_study_hours', 'online_classes_hours', 'social_media_hours',
#        'gaming_hours', 'sleep_hours', 'screen_time_hours', 'exercise_minutes',
#        'caffeine_intake_mg', 'part_time_job', 'upcoming_deadline',
#        'internet_quality', 'mental_health_score', 'focus_index',
#        'burnout_level', 'productivity_score', 'exam_score'],
#       dtype='object')

# %%
if 'age' not in df.columns:
    print("Kolom 'age' tidak ditemukan! Silakan cek kolom yang ada:", df.columns)
else:
  print(df[['age']].head())
# Out:
#    age
# 0   18
# 1   18
# 2   22
# 3   17
# 4   19

# %% [markdown]
# Kode tersebut digunakan untuk memastikan bahwa kolom age benar-benar ada di dalam dataset setelah data dibaca dan nama kolom dirapikan. Jika kolom ditemukan, program menampilkan lima data pertama dari kolom usia; jika tidak, akan muncul pesan peringatan. Langkah ini bertujuan untuk memverifikasi struktur data sebelum dilakukan analisis lanjutan agar terhindar dari kesalahan pemanggilan kolom.
